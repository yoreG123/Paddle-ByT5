# %%
# !pip uninstall paddlenlp -y
# !python byt5/tasks/tweetqa/run.py
# !pip install rouge_score
# Out:
# 0.040135130286216736
# ...
# 100%|█████████████████████████████████████| 2500/2500 [1:26:10<00:00,  2.07s/it]0.029389850795269012
# Exception ignored in: <function tqdm.__del__ at 0x7fd63bf02560>
# Traceback (most recent call last):
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/tqdm/_tqdm.py", line 931, in __del__
#     self.close()
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/tqdm/_tqdm.py", line 1133, in close
#     self._decr_instances(self)
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/tqdm/_tqdm.py", line 496, in _decr_instances
#     cls.monitor.exit()
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/tqdm/_monitor.py", line 52, in exit
#     self.join()
#   File "/opt/conda/envs/python35-paddle120-env/lib/python3.7/threading.py", line 1041, in join
#     raise RuntimeError("cannot join current thread")
# RuntimeError: cannot join current thread

# %%
# !python byt5/tasks/tweetqa/eval.py
# Out:
# W0215 03:25:19.538760 19137 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 10.1, Runtime API Version: 10.1
# W0215 03:25:19.544699 19137 device_context.cc:465] device: 0, cuDNN Version: 7.6.
# 100%|█████████████████████████████████████████████| 9/9 [00:26<00:00,  2.73s/it]
# #######################################
# rogueL: 69.60049337811762
# 65.68850536326065
# ##################################################
# ##################################################

# %%
import sys
import paddle
sys.path.append('byt5')
from paddlenlp.transformers import ByT5Tokenizer, T5ForConditionalGeneration

tokenizer = ByT5Tokenizer()
model = T5ForConditionalGeneration.from_pretrained('/home/aistudio/data/data126368/')
model.eval()

def get_answer(question, context):
    input_text = 'question: %s context: %s' % (question, context)
    inputs = tokenizer(input_text)
    print(inputs)
    input_ids = paddle.to_tensor(inputs['input_ids'])
    attention_mask = paddle.to_tensor(inputs['attention_mask'])
    # inputs.attention_mask.to('cuda')
    gen_kwargs = {
        "max_length": 127,
        "num_beams": 2,
        "length_penalty": 0.1,
        "early_stopping": True,
        "decode_strategy": "beam_search"
    }
    output = model.generate(input_ids=input_ids, attention_mask=attention_mask,**gen_kwargs,)
    return tokenizer.decode(output[0], skip_special_tokens=True)


context = "MONSTARS BASKETBALL @M0NSTARSBBALLWiggins answers Kemba's floater with a three! game tied 106-106. 8.9 to play. CHA ball!12/4/2016, 2:26:30 AM"
question = 'who answered kemba\'s "floater"?'     
    
get_answer(question, context)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_181/4012170300.py in <module>
#       2 import paddle
#       3 sys.path.append('byt5')
# ----> 4 from paddlenlp.transformers import ByT5Tokenizer, T5ForConditionalGeneration
#       5
#       6 tokenizer = ByT5Tokenizer()
#
# ImportError: cannot import name 'ByT5Tokenizer' from 'paddlenlp.transformers' (/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddlenlp/transformers/__init__.py)

# %%
l = ['w nj', 'forecast', 'he is losing it', 'endangeredriver', 'wiggins', 'game is tied at 106', '106106', 'kembas', 'shooting star', 'surprise', 'cnn', 'dog', 'tsonga', 'ahead of final match', 'westgate', 'my favorite mall', 'escaped', 'hole cut in wall', 'in unlikely event', '2009', 'donald trump', 'senator gillibrand', 'to speak in more vague terms', 'he wants to make them bombastic', 'pay attention to economy and ahca', 'mr alcohol', 'emilia clarke', 'alice oswalt', 'in universe', 'jimmykimmel', 'for effort', 'bb king', 'guitar', '15th', '174 yards', 'landondonovan', 'lagalaxy', 'chrisrock', 'chrisrock', 'chris spags', 'rihanna fans', 'nypd hats', 'officer moore', 'he was hit by pitch', 'donald gets things done', 'melania trump', '32 miles', 'helicopter pilot skills', 'paul walker', 'walker was young', 'when hes of voting age', 'mayor mark', 'breaking bad and wire', '20082013', 'cavs', 'espn', '16 years old', 'vegas', 'undermining democracies', 'sherlock holmes', 'facebook', 'us', 'dc', 'its new', 'gregcosell', 'football', 'amanda berry', 'cleveland', 'davidcassidy', 'proud and honored', 'cafe', 'local', 'justjem', 'lost significant other', 'krypton', 'prequel', 'rihanna', 'man', 'don grahams farewell party', 'honor', 'olympics', 'usa', 'do ya think im sexy', 'republic records', 'internet', 'net neutrality', 'usher', 'office workers', 'san bernardino', 'nate', '14', 'golden globes', 'black', 'we dont know', 'stuff that has been gone ofr 15 yars', '1', 'smosh', 'erdogan', 'abuse', 'two scarves and jacket', 'june', 'patricia arquette', 'half of her life', 'ellen degeneres and portia', 'ellentube', 'david levitz', 'stick together', 'protect dreamers', 'sundance', 'switzerland', 'dunkirk', 'whether he is going to die', 'sanders', '94 crime bill', 'grace vanderwaal', 'make her famous', 'ryan', 'jazz', 'to airwaves', 'wrote book or start podcast', 'for ranting', 'in violence', 'miranda', 'with pretty pink ring', 'anthony mackie', 'greece', 'turkish', 'kentucky', 'wallstar', 'harlots', 'romphim', 'russian connection', 'podium', 'melissa mccarthysean spicer', 'glory of lord', 'all flesh shall see it together', 'show staples your best office mug shot', 'coffee', 'martin luther king jr', 'light', 'donald trump', 'pizza rat', 'sad story', 'arie', 'real eggs', 'oprah', 'ciara russell', 'his kids', 'discovery', 'kevloria', 'aim', 'app', 'christine teigen', '150', 'luke skywalker', 'character work', 'dershowitz', 'cassell', 'mike nichols', 'graduate birdcage and spamalot', 'to spend more time with his pets', 'he was character', 'chicago', 'hispanic', 'barack obama', 'obamaday', 'macedonia', 'for taking photo', 'being in wheelchair', 'james harrison', 'zac efron', 'on cheek', 'usa today', 'they were not', 'thinkpieces', 'fyre festival', 'time', 'year and half', 'new record', 'sweden', 'fox news', 'four shot lead', 'last hole', 'their emotions', 'like you have multiple offers', 'iowa flag', 'midfield', 'ask sheev', 'protect american people', 'helping economy and bring more jobs', 'paul noma and cherrelle', 'harry potter play', 'official statement', 'shocked and heart broken', 'joss whedon', 'batgirl', 'nashville', 'taylor', '104', 'mike green', 'red wings', 'his pr team', 'zayn', 'at crowds mouths', 'prayers and hymns by heart', 'boogieman', 'kenien mentioned it', 'mcconaughey driving students', 'around surewalk', 'gma and taylor swift', 'whole new level yespls', 'president', 'liberation station', 'iroquois high school', 'grace aroune', 'malkin', 'mri', 'figures', 'michael keaton', 'lot of people', 'coachella', 'hating', 'donna elephant', 'they are nervous', 'verizon', 'boston', 'team usa', 'lockerroom', 'sterling k brown', 'so proud', 'tig', 'very sad', 'restroom', '2014', 'la', 'his own', 'this is what truth feel like tour', 'see dates and rsvp', 'upper hand', 'beyhive', 'tattoo', 'lebron', 'america', 'popular beers', 'ann coulter', 'delta', 'fred armisen', 'difficult people', 'governor jay nixon', 'so governor can visit north stl county', 'carlton', 'hotline bling', 'shia labeouf', 'how surveillance images can be manipulated and orchestrated', 'after shootaround', 'in shower', 'saturday night live', 'flats', 'gal godot', 'just bryzgalov', 'nhl all star game', 'selena abel', 'artists music', 'trevor story', 'rockies', 'purple', 'kate gosselin', 'rain and storms', 'central and eastern us', 'kim kardashian', 'gq', 'hanzal', 'boedker', 'black panther', 'memorable', 'her id', 'white house', 'marc jacobs', 'red cross', 'people', 'warriors', 'lakers jim buss', 'paris', 'u2', 'obama', 'that they had it good with obama', 'money23green', '3', 'dove', 'doris roberts', 'death', 'jsyk', '1032am', 'nrj awards', 'he had great time', 'that it was right decision', 'right coach', '1st intermission', 'new addition zamboni', 'sacramento', 'radio station', 'global hack', 'jim harbaugh', 'national anthem', 'lisa kudrow', 'smelly cat', '5 years ago', 'bachelor', 'she refuses', 'instyle opening conversation', 'it is beautiful', 'autotune', 'sounds like autotune', 'his dad', 'celtics jersey', 'maks', 'maksim c', 'steve bannon', '1903', '1883', 'jeff varner', '7', 'mayor of london', 'left wing students', 'culture of violence', 'speeches like this', 'american', 'kim kardashian', 'she was moving money around', 'tom hiddleston', 'red', 'antarctica', 'penguin', 'pope', 'night', 'michael dal colle', 'sonny milano', 'tom hiddleston', 'seven minutes', 'chester bennington', 'linkinpark', 'rock casbah', 'bill murray', 'condoleezza rice', 'very good', 'ariana', 'break free', '9', 'harden', '2', 'jury', 'murder', 'liam', 'artists', 'beauty and beast', 'emma watson', 'golden globes', 'halftime', 'ar', '5 minutes', 'coldplay for 5 minutes of leftshark', 'nyc', 'tom hiddleston', 'hard times', 'tennessee', '61 years', 'us', 'beach', 'martin luther king', 'james harden', '250k', 'gold', 'katie ledecky', 'anton yelchin', 'charlie bartlett and house of d', 'black panther', 'wealthy nation', 'r word', 'paper towns', 'snl', 'lot of himself', 'everyday heroes', 'as strong', 'for his resignation', 'new york times', 'grandchildren', 'christmas', 'russian officials', 'mostly negative', 'buckingham palace', 'royal air force', 'target', 'print dress', 'nail polish', 'theshoe', 'finalfive', 'floor', 'their contempt', 'billionaire class', 'black panther', 'new york', 'devastating news', 'simone biles', 'her bar routine', 'word', 'in movie', 'kerry', 'red', 'donalds', 'han solo', 'john legend', 'to see john legend', 'predators scored 3 goals', '219 time span', 'ellie goulding', '15mar', 'rand paul', '25apr', 'bachelor', 'olivia', 'it is ryans daughter', 'gilmore girls', 'lot of gilmore girls', 'martin luther king', 'martin luther king day', 'michael phelps', 'kevin durant and deandre jordan', 'apple watch', 'rolex', 'male he his', 'third', 'dlchamplin', 'crazy ex girlfriend', 'free', 'net neutrality', 'houston and brown', 'james comey', 'press', 'antilgbtq', 'her words mean nothing to him', 'london', 'no frauds', 'he is making things worse', 'sdcc', 'star wars fans', 'houston texans', 'moving out of 1st pick', 'gold', 'grandma', '20', 'womens us hockey program', '1997', 'hivaids', 'john lewis', 'what martin luther king jr would have done', 'justine bieber is here', 'justin beibers set live', 'kellyann conway', 'ed sheeran', 'gossip girls', 'muslim', 'trump supporters', 'mets', 'get it online', 'paul feig', 'all female cast', 'donald trump', '7', 'jacoby ellsbury', '1st', 'winner', 'mess with me', 'ceelo', 'mk purse', 'hero', 'movie', 'bon jovi in rock hall', 'votes posts and videos', 'jonathan drouin', 'will play on trip', 'you all', 'bow', '2 years', 'shark', 'skydance', 'foot imprints', 'kanyes', '50 minutes', 'justin timberlake', 'country album', 'canadian anthem', 'held up all lives matter card', 'elizabeth', 'bachelor', 'colonel sanders', 'rose', 'eyes to see', 'dream', 'excitement', 'stay in your seat kanye', 'revisiting waynes worls in 2015', 'somthing classy', 'mistake', 'fbi', 'serena williams', 'squeeze tiny fingers', 'basketball', 'victory for nets', 'thanksgiving', 'computer robots', 'colleges to pick', 'megan walker', 'black', 'at work', 'beauty and beast', 'gay moment', 'congress', 'great start', 'leslie jones', '2', 'luke donald', 'wine', 'ed sheeran', 'blisters', 'kotex bandages', 'zazie', 'domino', 'megynkelly', 'hidden agenda', 'whitehouse', 'nscvpress', 'colors', 'cardinalandgold', 'business', 'arkit eats', 'larry', 'post about larry', 'starwars concert attendees', 'going to show', 'mindy kaling', 'ava', 'tmoblie', 'copy of tapes', 'donald trump', '1000s of fans', 'home', 'regina george', 'election day', 'planned parenthood and ocare', 'dc', 'hbo done with nhl', '247 series', 'free pass', 'someones misfortune', 'covfefe of strangers', 'covfefe', 'gal gadot', 'chris hemsworth', 'gordon hayward', 'los angeles', 'justin timerblake', 'cma awards', 'george rr martin', 'heart attack', 'malcolm young', 'acdc', 'possession of controlled substance', 'canada', 'say anything negative', 'enjoy show', 'madison square garden', 'lacey holsworth and her family', 'mr drew scott', 'watch and vote', 'ariana grande', 'uk', 'president', 'down road', 'meme', 'dr maya angelou', 'bird', 'to introduce you to some people', 'harry ginny and albus potter', 'to be las vegas girl', 'very independent', 'every week so i can see snakes', 'im keeping that song secret', 'excited', 'write raps for young nicki', 'anxiety', 'her faith', 'friends', 'its with black cast', 'socks', 'george wh bush', 'south carolina south dakota utah', 'president', 'duchess of cambridge', 'they love it', 'russell wilson', 'mark rodgers', 'john', 'christine teigen', 'hamburg', 'people were hurt', 'justin bieber', 'whip', 'star trek', 'gilmore girls', 'given new life', 'slaughter competition', 'metgala', 'fast', 'champagne', 'in proam', 'his buddy', 'about being careful what you wish for', 'mcnugga', 'ariana', 'gay men', 'she got beat up', 'back outside with her brothers', 'love', 'hate', 'conservative', 'russians', 'corinne foxx', 'miss golden globes 2016', 'this nonsense', 'dallas', 'short skirt', 'christine teigen', '17s', 'yogi ferrell', 'rupauls drag race', 'chris hemsworth', 'd
exhausting', 'beyonce', 'lemonaid', 'spidermarble', 'black cat', 'dave mustaine', 'wmu football', 'in middle of night', 'alabama', 'cauldron', 'waynes world', 'raven and nick', 'paramonut and warners', 'imagining', 'introducing their newest custompainted aircraft', 'disneys frozen', 'because his team won', 'tha chacha of course', '44 inches', 'of course', 'of course', 'jules', 'friend', 'logic301 thegreatkhalid and alessiacara', 'sjps', 'sarah jessica parker and george malkemus', 'thoughts and wishes', 'getting back to work', 'darkening skin', 'zoe saldana', 'with faith', 'mountain of despair', 'tweet did not show', 'tweet did not show', 'space jam', 'kentucky', 'st thomas santa claus and cheese pasta', '17 hours', 'power', 'summer', 'zendaya', 'dolores oriordan', 'island records and love for music', 'benedict cumberbatch and tennis player', 'plays tennis', 'biden', 'everything she wants to say', 'drama', 'justinparty', 'pens locker room', 'live look', 'louis', 'katebolduan', 'larry', 'harry', 'tickle', 'manilla', 'matilda', 'gryffindor and ravenclaw', 'surewalk', 'browns win or season ends', 'for clarification', 'family', 'seth thomas', 'b marshall', 'humorous', 'blake lively', 'envy', 'kanye', 'sarcastic or cynical', 'jsu bus', 'his family', 'they did not affect him', 'shootings and death', 'for them to stop', 'gaga', 'perform', 'ming xi', 'leslie odom jr', '160 characters', '260 characters', 'steal peoples boyfriends', 'they were ruined', 'istanbul fans', 'turkey and greece', 'when does beyonce get here', 'national anthem', 'houston', 'hemsworth', 'ruffalo', 'black', 'presidents motorcade', 'stephen curry', 'when they grow up', 'nude pics but only kidding', 'bette midler', 'halftime show', 'lady gaga', 'every word said', 'rally for peace', 'for those who lost loved ones', 'arena', 'vancouver', 'very la song', 'sunset strip', 'bill', 'martin', 'michelle rodriguez', 'matt bomer', 'thugs', 'white', 'security guy', 'lose it', 'lee', 'if someone looked familiar', 'jj watt', 'amazing gift', 'gig harbor', 'narrows airport', 'mjolnir', 'steve or something', 'panel', 'every pollof debate', 'kiss', '10', 'tina fey', 'felicity jones', 'purple', 'black panther', 'trump presidencey', 'mr burns', 'light', 'wow', 'bright brilliant talent kind', 'he passed', 'jeff sessions', 'being naughty or nice', 'malia obama', 'malia obama', 'donald trump', 'donald trumps angry reaction', 'he kissed her', '2016', 'jeremy', '3', 'johnnys', 'his outfit', 'bush', 'bush didnt care about black people', 'leaked nudes', 'revenge porn', 'bennetton', 'haley', 'hailey baldwin', 'v', 'water bottle', 'downtown abbey', 'to take screenshot', 'jennifer aniston', 'vancouver canucks', 'pat quinn', 'steph curry', 'god', 'people in nhl management', 'eagles fans', 'over 80 catches', 'tcus punter', 'shawn oakman', 'hurricaneharvey', 'you', 'bathroom counter', 'rihanna', 'met gala', 'oscars bar', '100 am', 'vp biden and mariska', 'that beautiful scene', 'residentes verse', 'wrote my way out verse', 'in nola', 'you', 'lot', 'texting', 'harry potter', 'excited', 'thoughtful and committed', 'small', '10000', 'buffalo sabres', 'on camera', 'baton rouge', 'kyle chandler', 'comey', 'right side', 'america is trash', 'freedom', 'ann', 'right now', 'impassioned', 'texans players', 'bio', 'yall', 'amazing', '2017', '3', 'who she is', '2 many', 'deprogramming', 'oprah', 'juggling', 'cali', 'sad', 'give away his blunt', 'halloween', 'jeff gorton', '11', 'preacher lawson', 'tyra banks', 'san juan mayor', 'democrats', 'lebron', 'bb8', 'starwars cast', 'august', 'daily', 'to report incidents of bias', 'state celebrates differences', 'our troops', 'proudly', 'police man', 'right now', 'real donald trump', 'on great speech', 'duchess', 'flight simulator training session', 'on spotify', 'releasing her album tonight', 'media', 'mens health', 'his shirt', 'stephen', 'in airport', 'to listen to beyonce', 'to honor two or more legends', 'they belong to sport', 'that they have added to their family', 'it just gets better and better', 'two', 'bodega', 'indians', '22', 'run up to peoples homes', 'its dangerous', 'on casino boat', '50 passengers', 'around capitol']
##################################################
p = ['w nj', 'this forecast', 'rivers', 'endangeredriver', 'wiggins', '106106', '106106', 'kemba', 'looks like shes sad', 'someone has said to share', 'cnn', 'pizza eat dog', 'tsonga', 'ahead of his first match in davis cup final', 'westgate', 'there', 'escaped', 'as part of escape', 'unlikely event', '2009', 'sen gillibrand', 'sen gillibrand', 'to speak in vague and bombastic generalities', 'he is not vague but bombastic', 'ahca', 'mr alcohol', 'emilia clarke', 'alice oswalt', 'in universe', 'jimmykimmel', 'for effort', 'bb king', 'thousand notes', '15 hole', '174 yards', 'landondonovan', 'la galaxy', 'chrisrock', 'chrisrock', 'rihanna fans', 'rihanna fans', 'nypd hats', 'officer moore', 'he died', 'donald gets things done', 'melania trump', '32 miles', 'helicopter pilot skills', 'paul walker', 'he died', 'until we are old', 'mayor mark boughton', 'breaking bad', '200813', 'cavs', 'cavs', '16', 'to vegas', 'undermine democracies', 'sherlock holmes', 'facebook', 'us', 'dc comics', 'couple of days', 'gregcosell', 'football', 'amanda berry', 'cleveland', 'david cassidy', 'she is proud and honored', 'ice cream store', 'local', 'jemmye carroll', 'forever feels', 'man of steel', 'man of steel', 'madblackthot', 'homage', 'farewell party', 'honor', 'olympics', 'leslie jones', 'do ya think im sexy', 'republic records', 'internet', 'net neutrality', 'usher jimmyfallon and hamilton musical', 'office workers', 'san bernardino', 'td16', '14', 'golden globes', 'black', 'something happened', 'aim', '1', 'icymismosh', 'erdogan', 'export abuse against america', 'two scarves and jacket', 'june', 'patricia arquette', 'half half', 'portia', 'ellentube', 'david levitz', 'stick together', 'protect them', 'sundance', 'argentina', 'dunkirk', 'that they die in dunkirk', 'sanders', '94 crime bill', 'grace vander waal', 'that made her famous', 'snl', 'jazz', 'airwaves', 'write book or start podcast', 'venting to guys', 'in violence', 'miranda', 'pretty pink ring', 'anthony mackie', 'greece', 'turkish', 'kentucky', 'wallstar', 'harlots', 'romphim', 'russian connection nonsense', 'street', 'melissa mccarthysean spicer', 'glory of lord', 'all flesh', 'show us your best office mug shot', 'coffee', 'martin luther king jr', 'hate', 'realdonaldtrump', 'pizza rat', 'sad', 'arie', '3 legs', 'oprah', 'ciara russell', 'his kids', 'kevloria discovery', 'kevloriadiscovery', 'aim', 'app', 'christine teigen', '150', 'luke skywalker', 'character work', 'dershowitz', 'cassell', 'mike nichols', 'being titan', 'to spend more time with pets', 'because he will quit in peace', 'chicago', 'hispanics', 'mr president', 'mr president', 'macedonia', 'for taking photo', 'anyone on his team', 'j k simmons', 'zac efron', 'on cheek', 'dave majewski', '911 was fine with it', 'thinkpieces from fyrefestival attendees', 'fyre festival', 'victims', 'year and half', 'this record', 'sweden', 'fox news', '2ne', 'last', 'their emotions', 'like you have multiple offers', 'iowa flag', 'iowa', 'ask sheev', 'to protect american people', 'helping economy', 'paul noma and cherrelle', 'harry potter play', 'official statement', 'shocked and heartbroken', 'joss whedon', 'batgirl', 'nashville', 'taylor', 'section 104', 'red wings', 'mike green', 'his pr team', 'zayn', 'mouths', 'prayers and hymns', 'boogieman', 'alexander pettyton', 'to surewalk', 'to surewalk', 'yespls', 'new level', 'president', 'liberation station', 'iroquois high school', 'jimmy fallon', 'malkin', 'mri', 'hidden fences', 'michael keaton', 'lot of opple', 'coachella', 'lowkey', 'dona elephant', 'nervous', 'verizonstrike', 'boston', 'usa', 'team usa lockerroom', 'sterling kbrown', 'proud', 'tig', 'he thinks its sad', 'chara', '2014', 'los angeles', 'boyega', 'real tour', 'dates and rsvp', 'upper hand', 'beyhive', 'lebron james tattoo', 'lebron james', 'america', 'grain', 'ann coulter', 'delta', 'fred armisen', 'difficult people', 'gov jay nixon', 'to visit north stl county', 'carlton', 'hotline bling', 'shia labeouf', 'love story', 'during shots', 'at snl', 'snl', 'flats', 'gal gadot shuns', 'just bryzgalov', 'nhl all star', 'selena abel', 'release music together', 'rockies trevor story', 'rockies', 'purple', 'kate gosselin', 'rain and storms', 'memorial day weekend', 'kim kardashian', 'gq', 'hanzal', 'boedker', 'black panther', 'memorable', 'her id', 'white house', 'marc jacobs', 'red cross', 'people', 'warriors', 'jim buss', 'paris', 'paris', 'obama', 'trump presidency', 'money 23 green', 'three', 'dove', 'doris roberts', 'death', 'jsyk', '1032 am', 'nrj awards 2015', 'great time', 'its right decision', 'right coach', '1st intermission', 'new addition to peeps zamboni', 'sacramento', 'radio station', 'global', 'jim harbaugh', 'national anthem', 'lisa kudrow', 'smelly cat', '5 years', 'bachelor', 'he thinks it is nope', 'for opening convo', 'it is beautiful', 'autotune', 'he sounds like autotune', 'dad', 'celtics jersey', 'maks', 'maksim c', 'chief strategist steve bannon', '1903', '1883', 'jeff varner', 'at least', 'mayor of london', 'left wing', 'violence', 'speeches like this', 'american', 'kim kardashian west', 'cashing video game check', 'tom hiddleston', 'red solo', '15 penguin avenue', '15 penguin avenue', 'pope', 'at night', 'sonny milano', 'sonny milano', 'tom hiddleston', 'seven minutes', 'chester bennington', 'chester bennington', 'rock casbah panel', 'bill murray', 'role model', 'very good', 'billboard', 'break free', '9', 'celtics', 'two', 'jury', 'he murdered', 
matter', 'mario lebron', 'matthew perry', 'matthew perry', 'california', 'hopeful', 'lebron james', 'lebron james and michael jordan', 'kane guy', 'pretty good', 'nomove clause', 'three', 'ed sheeran', 'riverlands', 'it would enjoy', 'henry cavill', 'grease', 'her scalp', 'duchess of cambridge', 'kensington palace', 'children', 'heteronormative', 'trump', 'less than 3 years old', 'slowed it down', 'isaac h wright', 'bachelor', 'rian johnson', 'everyone', 'gibbons on martin', 'goals', 'candle', 'peach candle', 'elling yelling', 'stunts', 'paul mccartney', 'career', 'hope', 'she is giving her hope', 'december 7 2017', 'ed sheeran', 'alabama', '20point loss', 'kobe bryant', 'john williams', 'hate speech', 'king hall', '4th of july', 'taylor swift', 'it takes village', '1997', 'more than 6000', '6000', 'grab', 'ivy park', 'diane keaton', 'paul george', 'head of habitat intl', 'red sox', 'lester and lackey', 'empathy', 'everyone', 'trumps', 'great rack', 'nickkroll and stephen athome', 'david letterman', 'build wall', 'warren faye', 'warren', 'charlie coyle', 'keith', 'shia labeouf', 'singapore', 'iggy azalea', 'seems exhausting', 'beyonce', 'lemonade', 'spidermable', 'black cat', 'dave mustaine', 'wmu football', 'when she went to bed', 'alabama', 'cauldron', 'wayne', 'raven', 'paramount and warners', 'screaming about henry cavill', 'introducing newest custompainted aircraft', 'disneys frozen', 'he living his best super bowl', 'soccer', '3 years old', 'real', 'theres terror attack', 'friend jules', 'his friend', 'logic301 and alessia cara', 'sjps', 'jessica parker and george malkemus', 'her warm thoughts and well wishes', 'working', 'casting zoe saldana and darkenig her skin', 'zoe saldana', 'with this faith', 'with this faith', 'tweet did not show', 'tweet did not show', 'space jam', 'kentucky', 'st thomas santa claus and cheese pasta', '17 hours', 'power', 'summer issue', 'zendaya', 'dolores oriordan', 'island records', 'benedict cumberbatch', 'plays tennis', 'biden', 'everything she wants today', 'drama', 'justin party', 'pens locker room', 'live look in', 'louis', 'kate bolduan', 'larry', 'harry', 'tickle', 'manilla', 'matilda', 'gryffindor and ravenclaw', 'surewalk', 'browns win or end of season', 'for clarification', 'family of seth thomas', 'seth thomas', 'bill cosby', 'sarcastic', 'bachelor', 'sadness', 'kayne', 'dark', 'injuries', 'his family', 'per michel therrien', 'shootings and death', 'this is just crazy', 'gaga', 'floored', 'ming xi', 'leslie odom jr', '260 characters', '160', 'steal peoples boyfriends', 'she ruined it', 'istanbul', 'turkey and greece', 'when does beyonce get here', 'national anthem', 'sb51', 'hemsworth', 'ruffalo', 'black', 'presidents motorcade', 'stephen curry30', 'when he grow up', 'nudes', 'bette midler', 'halftime show', 'lady gaga', 'every word said', 'prince lost and lost', 'rally 4 peace', 'vancouver', 'vancouver', 'blue wonderful', 'sunset strip', 'buying gun', 'martin heinrich', 'matt bomer', 'matt bomer', 'thugs', 'white', 'security guy', 'lose it', 'lee', 'wow you look familiar', 'jj watt', 'gift', 'gig harbor', 'narrows airport in gig harbor', 'mjolnir', 'steve', 'frank luntz', 'debate', 'they get 10', '10 tho right', 'tina fey', 'felicity jones', 'purple carpet', 'black panther', 'trump presidency', 'mr burns', 'light', 'light stood up', 'bright brilliant talent', 'he died', 'jeff sessions', 'whos been naughty or nice', 'malia obama', 'malia obama', 'donald trump', 'being very mad about it', 'he kissed her', '2016', 'jeremy', '3', 'johnny depp’s goodwill', 'he thought by himself', 'bush', 'news', 'revenge porn', 'revenge porn', 'benetton', 'gov haley', 'hailey baldwin', 'v', 'waterbottle', 'downtown abbey', 'screenshot it', 'jennifer aniston', 'vancanucks', 'van canucks', 'steph', 'god', 'his people in nhl management', 'all eagles fans', '80', 'tcus punter', 'shawn oakman', 'hurricane harvey', 'cattie', 'bathroom counter', 'rihanna', 'met gala', 'oscars bar', 'about 1am', 'vp biden and mariska', 'that beautiful scene', 'residentes verse', 'his wrote his way out verse', 'in nola', 'joel embiid', 'lot one', 'they are calling', 'sharing it as well', 'exited', 'as group of thoughtful and committed', 'small group', '10', 'mcdavid buffalo sabres', 'freederay', 'baton rouge', 'kyle chandler', 'kyle chandler', 'right', 'that america is trash', 'really', 'ann coulter', 'right now', 'impassioned', 'players at texans', 'in bio', 'yall', 'amazing', '2017', '3 years', 'who she am', '2', 'they would make them 2 b cops', 'oprah', 'juggle bagels', 'cali', 'he is sad', 'by auctioneer', 'sethrogen halloween', 'jeff gorton', '11', 'preacher lawson', 'tyrabanks', 'mayor of san juan', 'trump', 'lebron 9', 'bb8', 'starwars cast', 'august', 'august', 'to report incidents of bias', 'to open statewide hotline number', 'their troops', 'proudly welcoming', 'police man', 'right now', 'donald trump', 'for his great speech', 'duchess', 'light simulator training', 'spotify', 'releasing her album', 'media', 'bill cosby', 'his shirt', 'stephen', 'airport', 'listen to beyonce', 'honor 3 legends of our sport', 'basketball', 'bunin oven', 'better and better', '2', 'bodega', 'indians', '22', 'running up to peoples homes', 'its dangerous', 'casino boat', '50 people', 'area']

# %%
import nltk
def postprocess_text(datas):
    datas = [data.strip() for data in datas]
    datas = ["\n".join(nltk.sent_tokenize(data[2:-3])) for data in datas]
    return datas
postprocess_text("MONSTARS BASKETBALL @M0NSTARSBBALLWiggins answers Kemba's floater with a three! game tied 106-106. 8.9 to play. CHA ball!12/4/2016, 2:26:30 AM")
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
import sys
sys.path.append('/home/aistudio/byt5')
sys.path.append('/home/aistudio/byt5/tasks/tweetqa')

import re
import string
import logging
import nltk
import paddle
from filelock import FileLock
from paddlenlp.datasets import load_dataset
from data import get_dev_dataloader
from tqdm.auto import tqdm
from paddlenlp.transformers import T5ForConditionalGeneration
from paddlenlp.transformers import ByT5Tokenizer
import argparse
import numpy as np
from rouge_score import rouge_scorer, scoring
from nltk.translate.bleu_score import sentence_bleu

try:
    nltk.data.find("tokenizers/punkt")
except (LookupError, OSError):
    with FileLock(".lock") as lock:
        nltk.download("punkt", quiet=True)

logger = logging.getLogger(__name__)

def normalize_text(text):
    """Normalize text for TweetQA task.
    Args:
        text: string
    Returns:
        normalized string
    """
    # Lower case.
    text = text.lower()
    # Remove punctuation.
    text = ''.join(ch for ch in text if ch not in set(string.punctuation))
    # Remove articles.
    text = re.sub(r'\b(a|an|the)\b', ' ', text)
    # Fix extra whitespaces.
    text = ' '.join(text.split())
    return text

def bleu1(targets, predictions):
  bleu_scores = []
  for target, prediction in zip(targets, predictions):
    target = normalize_text(target)
    prediction = normalize_text(prediction)

    # By setting the weights tuple to be (1, 0, 0, 0), only uni-grams are
    # counted towards the BLEU score, resulting in BLEU-1.
    score = sentence_bleu(
        [target.split()], prediction.split(), weights=(1, 0, 0, 0)) * 100

    bleu_scores.append(score)
  return {'bleu1': np.mean(bleu_scores)}

def compute(predictions, references, rouge_types=None, use_agregator=True,use_stemmer=False):
        if rouge_types is None:
            rouge_types = ["rouge1", "rouge2", "rougeL", "rougeLsum"]
        scorer = rouge_scorer.RougeScorer(rouge_types=rouge_types, use_stemmer=use_stemmer)
        if use_agregator:
            aggregator = scoring.BootstrapAggregator()
        else:
            scores = []
        for ref, pred in zip(references, predictions):
            score = scorer.score(ref, pred)
            if use_agregator:
                aggregator.add_scores(score)
            else:
                scores.append(score)

        if use_agregator:
            result = aggregator.aggregate()
        else:
            result = {}
            for key in scores[0]:
                result[key] = list(score[key] for score in scores)
        return result

def parse_args():
    parser = argparse.ArgumentParser(
        description="Evaluate ByT5 model on a summarize task"
    )
    parser.add_argument(
        "--model_name_or_path",
        type=str,
        default="/home/aistudio/data/data126377/",
        help="model_name_or_path",
    )
    parser.add_argument(
        "--evaluate_file",
        type=str,
        default="/home/aistudio/datasets/tweetqa/dev.json",
        help="evaluate_file.",
    )
    parser.add_argument(
        "--max_source_length",
        type=int,
        default=512,
        help="The maximum total input sequence length after "
        "tokenization.Sequences longer than this will be truncated, sequences shorter will be padded.",
    )
    parser.add_argument(
        "--max_target_length",
        type=int,
        default=128,
        help="The maximum total sequence length for target text after "
        "tokenization. Sequences longer than this will be truncated, sequences shorter will be padded."
        "during ``evaluate`` and ``predict``.",
    )
    parser.add_argument(
        "--num_beams",
        type=int,
        default=4,
        help="Number of beams to use for evaluation. This argument will be "
        "passed to ``model.generate``, which is used during ``evaluate`` and ``predict``.",
    )
    parser.add_argument(
        "--length_penalty",
        type=float,
        default=1.0,
        help="length_penalty",
    )
    parser.add_argument(
        "--eval_batch_size",
        type=int,
        default=1,
        help="Batch size (per device) for the evaluation dataloader.",
    )
    parser.add_argument(
        "--num_workers",
        type=int,
        default=0,
        help="num_workers.",
    )
    args = parser.parse_args()

    return args

# %%
args = parse_args()
# print(args.num_workers)
# Out:
# usage: ipykernel_launcher.py [-h] [--model_name_or_path MODEL_NAME_OR_PATH]
#                              [--evaluate_file EVALUATE_FILE]
#                              [--max_source_length MAX_SOURCE_LENGTH]
#                              [--max_target_length MAX_TARGET_LENGTH]
#                              [--num_beams NUM_BEAMS]
#                              [--length_penalty LENGTH_PENALTY]
#                              [--eval_batch_size EVAL_BATCH_SIZE]
#                              [--num_workers NUM_WORKERS]
# ipykernel_launcher.py: error: unrecognized arguments: -f /home/aistudio/.local/share/jupyter/runtime/kernel-61f21574-c51d-492e-a953-12436b8ea7f5.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
# args = parse_args()
# def postprocess_text(datas):
#     datas = [data.strip() for data in datas]
#     datas = ["\n".join(nltk.sent_tokenize(data[2:-3])) for data in datas]
#     return datas
# def postprocess_text(datas):
#     datas = [data for data in datas]
#     return datas


# model = T5ForConditionalGeneration.from_pretrained(args.model_name_or_path)
# model.eval()
# tokenizer = ByT5Tokenizer()
# eval_dataloader = get_dev_dataloader(tokenizer, args)
ds = load_dataset("tweetqa_paddle",splits=("train", "dev","test"))
datan = ds[1]
datan = [data['label'] for data in datan]
NOT_TRUNC_LABELS = datan

# gen_kwargs = {
#     "max_length": args.max_target_length - 1,
#     "num_beams": args.num_beams,
#     "length_penalty": args.length_penalty,
#     "early_stopping": True,
#     "decode_strategy": "beam_search"
# }
# rougel = RougeL()
# bleu = BLEU()


# all_preds = []
# with paddle.no_grad():
#     for batch in tqdm(eval_dataloader):
#         source_ids, source_mask, labels, target_mask = batch
#         generated_tokens = model.generate(
#             input_ids=source_ids,
#             attention_mask=source_mask,
#             **gen_kwargs,
#         )[0]
#         labels = np.where(labels.numpy() != -100, labels.numpy(), tokenizer.pad_token_id)
#         decoded_preds = tokenizer.batch_decode(
#             generated_tokens.numpy(), skip_special_tokens=True
#         )
#         # print('decodep:',decoded_preds)
#         decoded_preds = postprocess_text(decoded_preds)
#         all_preds.extend(decoded_preds)
# # for pred, label in zip(all_preds, NOT_TRUNC_LABELS):
# #     rougel.add_inst(pred, label)
# #     bleu.add_inst(pred, label)
# # resultl = rougel.score()
# # resultb = bleu.score()
# results = compute([normalize_text(data) for data in all_preds],[normalize_text(data) for data in NOT_TRUNC_LABELS])
# print(results)
# print('#######################################')
# print(results["rougeL"].mid.fmeasure)
# print (bleu1([normalize_text(data) for data in NOT_TRUNC_LABELS],[normalize_text(data) for data in all_preds]))
# print('##################################################')
# print([normalize_text(data) for data in NOT_TRUNC_LABELS])
# print('##################################################')
# print([normalize_text(data) for data in all_preds])
# # print('rougel:',resultl,'bleu:',resultb)
# paddle.save(all_preds, "all_preds.pd")

# %%
NOT_TRUNC_LABELS
# Out:
# [['w nj', 'w nj'],
#  ['the forecast', 'the forecast'],
#  ['he is losing it', 'it'],
#  ['#endangeredriver', '#endangereddriver'],
#  ['wiggins', 'wiggins'],
#  ['the game is tied at 106', '106-106'],
#  ['106-106', '106-106.'],
#  ["kemba's", "kemba's floater"],
#  ['a shooting star.', 'a shooting star'],
#  ['surprise.', 'surprise.'],
#  ['cnn.', 'cnn.'],
#  ['a dog.', 'the dog'],
#  ['tsonga.', 'tsonga'],
#  ['ahead of the final match.', 'daviscupfinal'],
#  ['westgate.', 'westgate.'],
#  ['my favorite mall.', 'westgate'],
#  ['escaped.', 'cut in the wall as part of escape'],
#  ['a hole cut in the wall.', 'cut in the wall'],
#  ['in the unlikely event.', 'in the unlikely event'],
#  ['2009', '2009'],
#  ['donald trump.', 'sen. gillebrand'],
#  ['senator gillibrand.', 'sen gillbrand'],
#  ['to speak in more vague terms.',
#   'speak in vague but bombastic generalities'],
#  ['he wants to make them bombastic.', 'good'],
# ...

# %%
pre = paddle.load('/home/aistudio/all_preds.pd')

# %%
# !pip install sacrebleu
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      |████████████████████████████████| 92kB 7.9MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 675kB 37.6MB/s eta 0:00:01
# ERROR: blackhole 1.0.1 has requirement numpy<=1.19.5, but you'll have numpy 1.20.3 which is incompatible.
# ERROR: blackhole 1.0.1 has requirement tabulate==0.8.3, but you'll have tabulate 0.8.9 which is incompatible.
# ...
#   Found existing installation: tabulate 0.8.3
#     Uninstalling tabulate-0.8.3:
#       Successfully uninstalled tabulate-0.8.3
# ...

# %%
import sacrebleu
def bleu(targets, predictions):
  """Computes BLEU score.
  Args:
    targets: list of strings or list of list of strings if multiple references
      are present.
    predictions: list of strings
  Returns:
    bleu_score across all targets and predictions
  """
  if isinstance(targets[0], list):
    print('is')
    targets = [[x for x in target] for target in targets]
    print(targets)
  else:
    # Need to wrap targets in another list for corpus_bleu.
    targets = [targets]

  bleu_score = sacrebleu.corpus_bleu(predictions, targets,
                                     smooth_method="exp",
                                     smooth_value=0.0,
                                     force=False,
                                     lowercase=False,
                                     tokenize="intl",
                                     use_effective_order=False)
  return {"bleu": bleu_score.score}

# %%
print(bleu(NOT_TRUNC_LABELS,pre))
# Out:
# is
# ...

# %%
ds[1][0]
ds[1][1]
ds[1][2]
# ds[1][3]
# ds[1][4]
# Out:
# {'Question': 'what is this user "losing"',
#  'label': ['he is losing it', 'it'],
#  'Tweet': "The #endangeredriver would be a sexy bastard in this channel if it had water. Quick turns. Narrow. (I'm losing it) John D. Sutter (@jdsutter) June 21, 2014",
#  'qid': 'f1c214d65d1cd73b457c1dba09f90013'}

# %%
pre
# Out:
# ['w nj',
#  'this forecast',
#  'rivers',
#  '#endangeredriver',
#  'wiggins',
#  '106-106',
#  '106-106',
#  'kemba',
#  "the looks like she's sad.",
#  'someone has said to share.',
#  'cnn',
#  'pizza, eat the dog',
#  'tsonga',
#  'ahead of his first match in davis cup final',
#  'westgate',
#  'there',
#  'escaped',
#  'as part of escape',
#  'the unlikely event',
#  '2009',
#  'sen gillibrand',
#  'sen gillibrand',
#  'to speak in vague and bombastic generalities',
#  'he is not vague but bombastic',
#  'ahca',
#  'mr. alcohol',
#  'emilia clarke',
#  'alice oswalt',
#  'in the universe',
#  '@jimmykimmel',
#  'for the effort.',
#  'bb king',
#  'a thousand notes',
#  'the 15 hole.',
#  '174 yards',
#  'landondonovan',
#  'la galaxy',
#  'chrisrock',
#  'chrisrock',
#  'rihanna fans',
#  'rihanna fans',
#  'nypd hats',
#  'officer moore',
#  'he died',
#  'donald gets things done',
#  'melania trump',
#  '32 miles',
#  'helicopter pilot skills',
#  'paul walker.',
# ...
