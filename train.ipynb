# %%
# !pip uninstall paddlenlp -y
# !python byt5/tasks/tweetqa/run.py
# Out:
# WARNING: Skipping paddlenlp as it is not installed.
# W0215 01:13:49.391083  7389 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 10.1, Runtime API Version: 10.1
# W0215 01:13:49.396780  7389 device_context.cc:465] device: 0, cuDNN Version: 7.6.
# caches/tweetqa_train.pkl
# ...
#  91%|█████████████████████████████████▋   | 17503/19200 [01:02<01:17, 22.01it/s]0.08361222594976425
# 0.05942723527550697
# 0.07609578222036362
# 0.07222124934196472
# 0.11992774158716202
# 0.06162748858332634
# 0.05476410314440727
# 0.05035834014415741
# 0.043145474046468735
# ...
#  91%|█████████████████████████████████▊   | 17550/19200 [02:39<56:37,  2.06s/it]0.04940200597047806
#
# ...
# 100%|█████████████████████████████████████████████| 9/9 [00:27<00:00,  2.86s/it]
# rogueL: 0.6890417951191425
# {'bleu1': 64.97890394671155}
# ...
#  92%|█████████████████████████████████▉   | 17600/19200 [04:55<56:49,  2.13s/it]0.08483418077230453
#
# ...
